# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName("Contador de Palavras") \
    .getOrCreate()

# %%
lines = spark.sparkContext.textFile("README.md")

# %%
wordCounts = lines.flatMap(lambda line: line.split(" ")).countByValue()

# %%
for word, count in wordCounts.items():
    print(f"{word}: {count}")
# Out:
# {"payload":{"allShortcutsEnabled":false,"fileTree":{"":{"items":[{"name":"Sprint0","path":"Sprint0","contentType":"directory"},{"name":"Sprint1","path":"Sprint1","contentType":"directory"},{"name":"Sprint2","path":"Sprint2","contentType":"directory"},{"name":"Sprint3","path":"Sprint3","contentType":"directory"},{"name":"Sprint4","path":"Sprint4","contentType":"directory"},{"name":"Sprint5","path":"Sprint5","contentType":"directory"},{"name":"Sprint6","path":"Sprint6","contentType":"directory"},{"name":"README.md","path":"README.md","contentType":"file"}],"totalCount":8}},"fileTreeProcessingTime":5.630222,"foldersToFetch":[],"repo":{"id":718116606,"defaultBranch":"main","name":"ProgramaBolsaCompass","ownerLogin":"edmilsonpmfilho","currentUserCanPush":false,"isFork":false,"isEmpty":false,"createdAt":"2023-11-13T12:18:36.000Z","ownerAvatar":"https://avatars.githubusercontent.com/u/75546716?v=4","public":true,"private":false,"isOrgOwned":false},"symbolsExpanded":false,"treeExpanded":true,"refInfo":{"name":"main","listCacheKey":"v0:1699877917.3418188","canEdit":false,"refType":"branch","currentOid":"29d1a83c9bd2191db419a98f0f0225b51c4668db"},"path":"README.md","currentUser":null,"blob":{"rawLines":null,"stylingDirectives":null,"csv":null,"csvError":null,"dependabotInfo":{"showConfigurationBanner":false,"configFilePath":null,"networkDependabotPath":"/edmilsonpmfilho/ProgramaBolsaCompass/network/updates","dismissConfigurationNoticePath":"/settings/dismiss-notice/dependabot_configuration_notice","configurationNoticeDismissed":null,"repoAlertsPath":"/edmilsonpmfilho/ProgramaBolsaCompass/security/dependabot","repoSecurityAndAnalysisPath":"/edmilsonpmfilho/ProgramaBolsaCompass/settings/security_analysis","repoOwnerIsOrg":false,"currentUserCanAdminRepo":false},"displayName":"README.md","displayUrl":"https://github.com/edmilsonpmfilho/ProgramaBolsaCompass/blob/main/README.md?raw=true","headerInfo":{"blobSize":"615: 1
# Bytes","deleteInfo":{"deleteTooltip":"You: 1
# must: 2
# be: 2
# signed: 2
# in: 2
# to: 2
# make: 2
# or: 2
# propose: 2
# changes"},"editInfo":{"editTooltip":"You: 1
# changes"},"ghDesktopPath":"https://desktop.github.com","gitLfsPath":null,"onBranch":true,"shortPath":"1d844f2","siteNavLoginPath":"/login?return_to=https%3A%2F%2Fgithub.com%2Fedmilsonpmfilho%2FProgramaBolsaCompass%2Fblob%2Fmain%2FREADME.md","isCSV":false,"isRichtext":true,"toc":[{"level":1,"text":"ProgramaBolsaCompass","anchor":"programabolsacompass","htmlText":"ProgramaBolsaCompass"},{"level":2,"text":"Apresentação","anchor":"apresentação","htmlText":"Apresentação"},{"level":2,"text":"Sprints","anchor":"sprints","htmlText":"Sprints"}],"lineInfo":{"truncatedLoc":"28","truncatedSloc":"20"},"mode":"file"},"image":false,"isCodeownersFile":null,"isPlain":false,"isValidLegacyIssueTemplate":false,"issueTemplateHelpUrl":"https://docs.github.com/articles/about-issue-and-pull-request-templates","issueTemplate":null,"discussionTemplate":null,"language":"Markdown","languageID":222,"large":false,"loggedIn":false,"newDiscussionPath":"/edmilsonpmfilho/ProgramaBolsaCompass/discussions/new","newIssuePath":"/edmilsonpmfilho/ProgramaBolsaCompass/issues/new","planSupportInfo":{"repoIsFork":null,"repoOwnedByCurrentUser":null,"requestFullPath":"/edmilsonpmfilho/ProgramaBolsaCompass/blob/main/README.md","showFreeOrgGatedFeatureMessage":null,"showPlanSupportBanner":null,"upgradeDataAttributes":null,"upgradePath":null},"publishBannersInfo":{"dismissActionNoticePath":"/settings/dismiss-notice/publish_action_from_dockerfile","releasePath":"/edmilsonpmfilho/ProgramaBolsaCompass/releases/new?marketplace=true","showPublishActionBanner":false},"rawBlobUrl":"https://github.com/edmilsonpmfilho/ProgramaBolsaCompass/raw/main/README.md","renderImageOrRaw":false,"richText":"<article: 1
# class=\"markdown-body: 1
# entry-content: 1
# container-lg\": 1
# itemprop=\"text\"><h1: 1
# tabindex=\"-1\": 6
# dir=\"auto\"><a: 3
# id=\"user-content-programabolsacompass\": 1
# class=\"anchor\": 3
# aria-hidden=\"true\": 3
# href=\"#programabolsacompass\"><svg: 1
# class=\"octicon: 3
# octicon-link\": 3
# viewBox=\"0: 3
# 0: 117
# 16: 3
# 16\": 3
# version=\"1.1\": 3
# width=\"16\": 3
# height=\"16\": 3
# aria-hidden=\"true\"><path: 3
# d=\"m7.775: 3
# 3.275: 3
# 1.25-1.25a3.5: 3
# 3.5: 12
# 1: 24
# 4.95: 6
# 4.95l-2.5: 3
# 2.5a3.5: 3
# 1-4.95: 3
# .751.751: 6
# .018-1.042.751.751: 3
# 1.042-.018: 3
# 1.998: 18
# 2.83: 6
# 0l2.5-2.5a2.002: 3
# 2.002: 3
# 0-2.83-2.83l-1.25: 3
# 1.25a.751.751: 3
# 1-1.042-.018.751.751: 3
# 1-.018-1.042Zm-4.69: 3
# 9.64a1.998: 3
# 0l1.25-1.25a.751.751: 3
# 1.042.018.751.751: 3
# .018: 3
# 1.042l-1.25: 3
# 1.25a3.5: 3
# 1-4.95-4.95l2.5-2.5a3.5: 3
# 1-.018: 3
# 1.042.751.751: 3
# 1-1.042.018: 3
# 0-2.83: 3
# 0l-2.5: 3
# 2.5a1.998: 3
# 2.83Z\"></path></svg></a>ProgramaBolsaCompass</h1>\n<h2: 1
# id=\"user-content-apresentação\": 1
# href=\"#apresentação\"><svg: 1
# 2.83Z\"></path></svg></a>Apresentação</h2>\n<p: 1
# dir=\"auto\">Olá!: 1
# Meu: 1
# nome: 1
# é: 1
# Edmilson: 1
# Pessôa: 1
# de: 3
# Melo: 1
# Filho\n </p>\n<p: 1
# dir=\"auto\">Tenho: 1
# 25: 1
# anos: 1
# e: 1
# sou: 1
# da: 2
# cidade: 1
# Paulista-PE\n </p>\n<p: 1
# dir=\"auto\">Estou: 1
# indo: 1
# para: 1
# o: 1
# 7º: 1
# período: 1
# Sistemas: 1
# Informação,: 1
# pela: 2
# faculdade: 1
# Uninassau-Graças/Recife-PE.\nFormado: 1
# em: 1
# Gastronomia: 1
# Faculdade: 1
# Senac: 1
# Pernambuco.</p>\n<h2: 1
# id=\"user-content-sprints\": 1
# href=\"#sprints\"><svg: 1
# 2.83Z\"></path></svg></a>Sprints</h2>\n<ul: 1
# class=\"contains-task-list\">\n<li: 1
# class=\"task-list-item\"><input: 11
# type=\"checkbox\": 11
# id=\"\": 11
# disabled=\"\": 11
# class=\"task-list-item-checkbox\": 7
# checked=\"\">: 7
# <a: 11
# href=\"/edmilsonpmfilho/ProgramaBolsaCompass/blob/main/Sprint0\">Sprint: 1
# 0</a></li>\n<li: 1
# href=\"/edmilsonpmfilho/ProgramaBolsaCompass/blob/main/Sprint1\">Sprint: 1
# 1</a></li>\n<li: 1
# href=\"/edmilsonpmfilho/ProgramaBolsaCompass/blob/main/Sprint2\">Sprint: 1
# 2</a></li>\n<li: 1
# href=\"/edmilsonpmfilho/ProgramaBolsaCompass/blob/main/Sprint3\">Sprint: 1
# 3</a></li>\n<li: 1
# href=\"/edmilsonpmfilho/ProgramaBolsaCompass/blob/main/Sprint4\">Sprint: 1
# 4</a></li>\n<li: 1
# href=\"/edmilsonpmfilho/ProgramaBolsaCompass/blob/main/Sprint5\">Sprint: 1
# 5</a></li>\n<li: 1
# href=\"/edmilsonpmfilho/ProgramaBolsaCompass/blob/main/Sprint6\">Sprint: 1
# 6</a></li>\n<li: 1
# class=\"task-list-item-checkbox\">: 4
# href=\"/edmilsonpmfilho/ProgramaBolsaCompass/blob/main/Sprint7\">Sprint: 1
# 7</a></li>\n<li: 1
# href=\"/edmilsonpmfilho/ProgramaBolsaCompass/blob/main/Sprint8\">Sprint: 1
# 8</a></li>\n<li: 1
# href=\"/edmilsonpmfilho/ProgramaBolsaCompass/blob/main/Sprint9\">Sprint: 1
# 9</a></li>\n<li: 1
# href=\"/edmilsonpmfilho/ProgramaBolsaCompass/blob/main/Sprint10\">Sprint: 1
# 10</a></li>\n</ul>\n</article>","renderedFileInfo":null,"shortPath":null,"symbolsEnabled":true,"tabSize":8,"topBannersInfo":{"overridingGlobalFundingFile":false,"globalPreferredFundingPath":null,"repoOwner":"edmilsonpmfilho","repoName":"ProgramaBolsaCompass","showInvalidCitationWarning":false,"citationHelpUrl":"https://docs.github.com/github/creating-cloning-and-archiving-repositories/creating-a-repository-on-github/about-citation-files","showDependabotConfigurationBanner":false,"actionsOnboardingTip":null},"truncated":false,"viewable":true,"workflowRedirectUrl":null,"symbols":{"timed_out":false,"not_analyzed":false,"symbols":[{"name":"ProgramaBolsaCompass","kind":"section_1","ident_start":2,"ident_end":22,"extent_start":0,"extent_end":615,"fully_qualified_name":"ProgramaBolsaCompass","ident_utf16":{"start":{"line_number":0,"utf16_col":2},"end":{"line_number":0,"utf16_col":22}},"extent_utf16":{"start":{"line_number":0,"utf16_col":0},"end":{"line_number":28,"utf16_col":0}}},{"name":"Apresentação","kind":"section_2","ident_start":28,"ident_end":42,"extent_start":25,"extent_end":316,"fully_qualified_name":"Apresentação","ident_utf16":{"start":{"line_number":3,"utf16_col":3},"end":{"line_number":3,"utf16_col":15}},"extent_utf16":{"start":{"line_number":3,"utf16_col":0},"end":{"line_number":15,"utf16_col":0}}},{"name":"Sprints","kind":"section_2","ident_start":319,"ident_end":326,"extent_start":316,"extent_end":615,"fully_qualified_name":"Sprints","ident_utf16":{"start":{"line_number":15,"utf16_col":3},"end":{"line_number":15,"utf16_col":10}},"extent_utf16":{"start":{"line_number":15,"utf16_col":0},"end":{"line_number":28,"utf16_col":0}}}]}},"copilotInfo":null,"copilotAccessAllowed":false,"csrf_tokens":{"/edmilsonpmfilho/ProgramaBolsaCompass/branches":{"post":"3h5UvMNxX-c6xSgIsVCMfqc-9IC5YDXSg7XqrszzSzzO0KpDN9TNGfvcRd8GhEwfQI85zygc4KoQ0YCKnZfPug"},"/repos/preferences":{"post":"ol75-Op1qXHodDaZ81GclBX9hX5yI_j9tove4x6d9sy4Qu1BnSFF0Z4CkoMvrpfGP6WzJHKFdnCp8glFW4C4Jw"}}},"title":"ProgramaBolsaCompass/README.md: 1
# at: 1
# main: 1
# ·: 1
# edmilsonpmfilho/ProgramaBolsaCompass"}: 1
